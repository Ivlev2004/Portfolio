# %% [markdown]
# ### Тема задания: «Реализация собственного пакета модулей по манипулированию табличными данными».

# %%
from Pract \
    import module_csv as mc, \
    module_pickle as mp, \
    module_text as mt, \
    basic_opers as bo

database = [['A', '(str)', 'B', '(fl)', 'C', '(int)', 'D', '(bl)'],
            ['1', 2, 3, True],
            ['4', 5, 6, False],
            ['7', 8, 9, True]]

mc.save_table(database, 'database')
mc.save_table(database, 'database', 2)
mp.save_table(database, 'database')
mt.save_table(database, 'database')
database = mc.load_table('database')
database = mc.load_table('table1', 'table2')
bo.print_table(database)

database = [['A', '', 'B', '', 'C', '', 'D', ''],
            ['1', 2, 3, True],
            ['4', 5, 6, False],
            ['7', 8, 9, True]]

mp.save_table(database, 'database')
database = mp.load_table('database')
bo.print_table(database)
bo.get_rows_by_number(database)
print('------------------------')
bo.get_rows_by_index(database, '4', '1')
print('------------------------')
types_dict = bo.get_column_types(database)
print(types_dict)
bo.set_column_types(types_dict, database)
print('------------------------')
print(bo.get_column_types(database, False))
print('------------------------')
bo.get_values(database)
print('------------------------')
bo.get_values(database, 3)
print('------------------------')
bo.get_values(database, 'D')
print('------------------------')
bo.set_values(database)
print('------------------------')
bo.set_values(database, 3)
print('------------------------')
bo.set_values(database, 'B')
print('------------------------')
table1 = mc.load_table('table1')
print('------------------------')
table2 = mc.load_table('table2')
print('------------------------')
database = bo.concat(table1, table2)
bo.print_table(database)
print('------------------------')
table1, table2 = bo.split(database, 3)
bo.print_table(table1)
print('------------------------')
bo.print_table(table2)
# Out:
# Таблица успешно загружена
# Таблица успешно загружена
# Таблица успешно загружена
#   ['A', '(str)', 'B', '(fl)', 'C', '(int)', 'D', '(bl)']
# 1 ['1', 2.0, 3, True]
# 2 ['4', 5.0, 6, True]
# 3 ['7', 8.0, 9, True]
# Таблица успешно загружена
#   ['A', '(str)', 'B', '(int)', 'C', '(int)', 'D', '(bl)']
# 1 ['1', 2, 3, True]
# 2 ['4', 5, 6, False]
# 3 ['7', 8, 9, True]
# Введите значения!!!
# Начало:1
# Конец:4
# В таблице: 3 строки, а не  4
#   ['A', '(str)', 'B', '(int)', 'C', '(int)', 'D', '(bl)']
# 1 ['1', 2, 3, True]
# 2 ['4', 5, 6, False]
# 3 ['7', 8, 9, True]
# ------------------------
#   ['A', '(str)', 'B', '(int)', 'C', '(int)', 'D', '(bl)']
# 1 ['1', 2, 3, True]
# 2 ['4', 5, 6, False]
# ------------------------
# {1: '(str)', 2: '(int)', 3: '(int)', 4: '(bl)'}
#   ['A', '(str)', 'B', '(int)', 'C', '(int)', 'D', '(bl)']
# 1 ['1', 2, 3, True]
# 2 ['4', 5, 6, False]
# 3 ['7', 8, 9, True]
# ------------------------
# {'A': '(str)', 'B': '(int)', 'C': '(int)', 'D': '(bl)'}
# ...
